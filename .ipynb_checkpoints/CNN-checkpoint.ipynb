# %%
import sys
sys.version
sys.version_info
# Out:
# sys.version_info(major=3, minor=6, micro=5, releaselevel='final', serial=0)

# %%
from keras.utils import to_categorical
import numpy as np
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
TRAIN_LAB_PATH = "./data/train_labels.csv"
PREPROCESSED_TRAINING = "./data/processedData.npy"
PREPROCESSED_KAGGLE = "./data/processed_kaggle.npy"
PREPROCESSED_ENCODER_TRAINING = "./data/autoencoder_2018-11-20.npy"

# %%
CATEGORIES = ['apple', 'empty', 'moustache', 'mouth', 'mug', 'nail', 'nose', 'octagon', 'paintbrush', 'panda', 'parrot', 'peanut', 'pear', 'pencil', 'penguin', 'pillow', 'pineapple', 'pool', 'rabbit', 'rhinoceros', 'rifle', 'rollerskates', 'sailboat', 'scorpion', 'screwdriver', 'shovel', 'sink', 'skateboard', 'skull', 'spoon', 'squiggle']

def getIndexOf(category):
    return CATEGORIES.index(category)

def getCategoryOf(index):
    return CATEGORIES[index]

def load(infile):
    unformatted_images = np.load(infile, encoding='bytes')
    formatted = []
    for i,img in enumerate(unformatted_images):
        formatted.append([i, img[0]])
    return formatted

def loadAnthony(infile):
    unformatted_images = np.load(infile, encoding='bytes')
    formatted = []
    for i,img in enumerate(unformatted_images):
        formatted.append([i, img])
    return formatted
    

def formatXData(X, xDimension = 40):
    X = np.asarray(X)
    # Convert to matrix form
    X = X.reshape(-1, xDimension, xDimension, 1)
    # Convert to float
    X = X.astype('float32')
    # Scale pixel values between 0 and 1
    X = X / 255
    return X.astype('float32')

def addRotations(X,y):
    newX = []
    newY = []
    for i,XMatrix in enumerate(X):
        newX.append(XMatrix)
        newY.append(y[i])
        newX.append(np.rot90(XMatrix, 1))
        newY.append(y[i])
        newX.append(np.rot90(XMatrix, 2))
        newY.append(y[i])
        newX.append(np.rot90(XMatrix, 3))
        newY.append(y[i])
    return np.asarray(newX),np.asarray(newY)

def formatData(images, labels, xDimension = 40):
    categories = list(set(labels['Category']))
    X = []
    y = []
    for i, img in enumerate(images):
        label = labels.at[i,'Category']
        categoryNum = getIndexOf(label)
        X.append(img[1])
        y.append(categoryNum)
    y = to_categorical(y)
    X = formatXData(X, xDimension)
    return X.astype('float32'), y

def split(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
    X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=1) 
    return X_train, y_train, X_test, y_test, X_val, y_val

# %%
training_imgs = load(PREPROCESSED_ENCODER_TRAINING)
t = np.asarray(training_imgs)
print(np.asarray(training_imgs))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-37555b5caa7f> in <module>
#       1 training_imgs = load(PREPROCESSED_ENCODER_TRAINING)
# ----> 2 t = np.asarray(training_imgs)
#       3 print(np.asarray(training_imgs))
#
# /usr/local/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# ValueError: setting an array element with a sequence.

# %%
labels = pd.read_csv(TRAIN_LAB_PATH
# Out:
# 10000

# %%
X,y = formatData(training_imgs, labels)
# Out:
# 250 10000

# %%
# X,y = addRotations(X,y)

# %%
X_train, y_train, X_test, y_test, X_val, y_val = split(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b9101aa947f7> in <module>
# ----> 1 X_train, y_train, X_test, y_test, X_val, y_val = split(X,y)
#
# <ipython-input-4-a157eeb132ec> in split(X, y)
#      52
#      53 def split(X,y):
# ---> 54     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
#      55     X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=1)
#      56     return X_train, y_train, X_test, y_test, X_val, y_val
#
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2072         test_size = 0.25
#    2073
# -> 2074     arrays = indexable(*arrays)
#    2075
#    2076     if shuffle is False:
#
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     253         else:
#     254             result.append(np.array(X))
# --> 255     check_consistent_length(*result)
#     256     return result
#     257
#
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     228     if len(uniques) > 1:
#     229         raise ValueError("Found input variables with inconsistent numbers of"
# --> 230                          " samples: %r" % [int(l) for l in lengths])
#     231
#     232
#
# ValueError: Found input variables with inconsistent numbers of samples: [250, 10000]

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from sklearn.ensemble import RandomForestClassifier
from keras import regularizers

# %%
import csv
import matplotlib.pyplot as plt
import time

# %%
batch_size = 64
epochs = 40
num_classes = len(CATEGORIES)

# %%
def plotHistory(history):
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    
def createModel(input_shape=(40, 40, 1)):
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 kernel_initializer='he_normal',
                 input_shape=input_shape))

    model.add(MaxPooling2D((2, 2)))
#     model.add(Dropout(0.25))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Dropout(0.4))
    model.add(Conv2D(512, (3, 3), activation='relu'))
    model.add(Dropout(0.3))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])
    model.summary()
    return model

def createModel2(input_shape=(40, 40, 1)):
        # INPUT -> [CONV -> RELU -> CONV -> RELU -> POOL]*3 -> [FC -> RELU]*2 -> FC
    model = Sequential()
    #Input
    model.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     kernel_initializer='he_normal',
                     input_shape=input_shape))
    
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))
    model.add(Conv2D(256, (3, 3), activation='relu'))
    model.add(Conv2D(256, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
#     model.add(Dense(256, activation='relu'))
#     model.add(Dense(256, activation='relu'))
    model.add(Dense(256, kernel_regularizer=keras.regularizers.l2(0.3)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(256, kernel_regularizer=keras.regularizers.l2(0.2)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])
    model.summary()
    return model

def leNet4():
    # create model
    model = Sequential()
    
    # Convolution
    model.add(Conv2D(4, (4, 4), input_shape=(40, 40,1), activation='relu'))

    # Subsampling
    model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.1))
    
    # 2nd convolution layer
    model.add( Conv2D(16, (3, 3), activation='relu'))
    
    # Subsamplingmodel.add( Conv2D(64, (2, 2), activation='relu',


    model.add(MaxPooling2D(pool_size=(2, 2)))
    #model.add(Dropout(0.1))
    
    model.add(Flatten())
    model.add(Dense(120, kernel_regularizer=keras.regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

#    model.add(Dropout(0.4))
    
    model.add(Dense(128), )
    model.add(BatchNormalization())
    model.add(Activation('relu'))
#     model.add(Dropout(0.4))
    
    model.add(Dense(40), )
    model.add(BatchNormalization())
    model.add(Activation('relu'))

#     model.add(Dropout(0.2))
    
    model.add(Dense(31))
    model.add(Activation('softmax'))
    
    
    # Compile model
    model.compile(loss=keras.losses.categorical_crossentropy, 
                  optimizer=keras.optimizers.Adam(),
                  metrics=['accuracy'])
    
    model.summary()
    return model

# %%
model1 = createModel()
history = model1.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val, y_val))
score = model1.evaluate(X_test, y_test, verbose=0)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_80 (Conv2D)           (None, 38, 38, 32)        320
# _________________________________________________________________
# max_pooling2d_52 (MaxPooling (None, 19, 19, 32)        0
# _________________________________________________________________
# conv2d_81 (Conv2D)           (None, 17, 17, 64)        18496
# _________________________________________________________________
# max_pooling2d_53 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_82 (Conv2D)           (None, 6, 6, 128)         73856
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_83 (Conv2D)           (None, 4, 4, 512)         590336
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 8192)              0
# _________________________________________________________________
# dense_74 (Dense)             (None, 512)               4194816
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_75 (Dense)             (None, 31)                15903
# =================================================================
# Total params: 4,895,775
# Trainable params: 4,894,751
# Non-trainable params: 1,024
# _________________________________________________________________
# Train on 8000 samples, validate on 1000 samples
# Epoch 1/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 2.6904 - acc: 0.2629 - val_loss: 2.5516 - val_acc: 0.3070
# Epoch 2/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 1.9485 - acc: 0.4459 - val_loss: 2.3349 - val_acc: 0.3780
# Epoch 3/40
# 8000/8000 [==============================] - 22s 3ms/step - loss: 1.6424 - acc: 0.5307 - val_loss: 1.8040 - val_acc: 0.4750
# Epoch 4/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 1.4215 - acc: 0.5927 - val_loss: 1.8095 - val_acc: 0.4780
# Epoch 5/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 1.2780 - acc: 0.6296 - val_loss: 1.3285 - val_acc: 0.6410
# Epoch 6/40
# 8000/8000 [==============================] - 22s 3ms/step - loss: 1.1298 - acc: 0.6700 - val_loss: 1.2507 - val_acc: 0.6570
# Epoch 7/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.0229 - acc: 0.6994 - val_loss: 1.1643 - val_acc: 0.6850
# Epoch 8/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.9143 - acc: 0.7260 - val_loss: 1.2285 - val_acc: 0.6900
# Epoch 9/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.8170 - acc: 0.7531 - val_loss: 1.1632 - val_acc: 0.6870
# Epoch 10/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.7429 - acc: 0.7719 - val_loss: 1.1734 - val_acc: 0.6840
# Epoch 11/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.6634 - acc: 0.7966 - val_loss: 1.2165 - val_acc: 0.6870
# Epoch 12/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.5909 - acc: 0.8131 - val_loss: 1.1791 - val_acc: 0.6960
# Epoch 13/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0
train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val, y_val))
plotHistory(history)
score = model2.evaluate(X_test, y_test, verbose=0)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_41 (Conv2D)           (None, 38, 38, 32)        320
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 36, 36, 64)        18496
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 34, 34, 64)        36928
# _________________________________________________________________
# max_pooling2d_35 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 15, 15, 128)       73856
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 13, 13, 128)       147584
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 4, 4, 256)         295168
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 2, 2, 256)         590080
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_59 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_60 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_61 (Dense)             (None, 31)                7967
# =================================================================
# Total params: 1,301,983
# Trainable params: 1,301,983
# Non-trainable params: 0
# _________________________________________________________________
# Train on 6000 samples, validate on 2000 samples
# Epoch 1/40
# 6000/6000 [==============================] - 56s 9ms/step - loss: 3.1137 - acc: 0.1177 - val_loss: 2.7423 - val_acc: 0.2040
# Epoch 2/40
# 6000/6000 [==============================] - 54s 9ms/step - loss: 2.5232 - acc: 0.2527 - val_loss: 2.3310 - val_acc: 0.3135
# Epoch 3/40
# 6000/6000 [==============================] - 53s 9ms/step - loss: 2.2064 - acc: 0.3503 - val_loss: 2.0373 - val_acc: 0.3940
# Epoch 4/40
# 6000/6000 [==============================] - 53s 9ms/step - loss: 1.9086 - acc: 0.4268 - val_loss: 1.9985 - val_acc: 0.4370
# Epoch 5/40
# 6000/6000 [==============================] - 53s 9ms/step - loss: 1.6632 - acc: 0.5173 - val_loss: 1.7138 - val_acc: 0.5065
# Epoch 6/40
# 6000/6000 [==============================] - 55s 9ms/step - loss: 1.5028 - acc: 0.5613 - val_loss: 1.6461 - val_acc: 0.5585
# Epoch 7/40
# 6000/6000 [==============================] - 56s 9ms/step - loss: 1.3166 - acc: 0.6202 - val_loss: 1.5605 - val_acc: 0.5770
# Epoch 8/40
# 6000/6000 [==============================] - 56s 9ms/step - loss: 1.2069 - acc: 0.6435 - val_loss: 1.4851 - val_acc: 0.5850
# Epoch 9/40
# 6000/6000 [==============================] - 57s 9ms/step - loss: 1.0466 - acc: 0.6880 - val_loss: 1.4520 - val_acc: 0.6090
# Epoch 10/40
# 6000/6000 [==============================] - 53s 9ms/step - loss: 0.9453 - acc: 0.7147 - val_loss: 1.4632 - val_acc: 0.6225
# Epoch 11/40
# 6000/6000 [==============================] - 53s 9ms/step - loss: 0.8465 - acc: 0.7412 - val_loss: 1.4200 - val_acc: 0.6405
# Epoch 32/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.1814 - acc: 0.9412 - val_loss: 1.9690 - val_acc: 0.6450
# Epoch 33/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.2076 - acc: 0.9370 - val_loss: 2.0603 - val_acc: 0.6460
# Epoch 34/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.1704 - acc: 0.9432 - val_loss: 2.1820 - val_acc: 0.6415
# Epoch 35/40
# 6000/6000 [==============================] - 51s 9ms/step - loss: 0.1941 - acc: 0.9418 - val_loss: 1.9650 - val_acc: 0.6620
# Epoch 36/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.1638 - acc: 0.9512 - val_loss: 2.1179 - val_acc: 0.6505
# Epoch 37/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.1646 - acc: 0.9500 - val_loss: 2.0421 - val_acc: 0.6655
# Epoch 38/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.1321 - acc: 0.9567 - val_loss: 2.2303 - val_acc: 0.6600
# Epoch 39/40
# 6000/6000 [==============================] - 55s 9ms/step - loss: 0.1622 - acc: 0.9487 - val_loss: 2.0291 - val_acc: 0.6535
# Epoch 40/40
# 6000/6000 [==============================] - 54s 9ms/step - loss: 0.1335 - acc: 0.9583 - val_loss: 2.2310 - val_acc: 0.6525

# %%
score
# Out:
# [1.6774757614135742, 0.6775]

# %%
preprocessed_kaggle_2 = load(PREPROCESSED_KAGGLE)
X_kaggle_2 = formatXData(list(map(lambda x: x[1], preprocessed_kaggle_2)))
kaggle_predictions_2 = model2.predict(X_kaggle_2)

# %%
ts = time.time()
timestamp = int(ts)
savePredictions('./models/model2/prediction_'+ str(timestamp) + '_' + str(score[1]) + '.csv', kaggle_predictions_2)

# %%
# With L2 regaularization
model2L2Reg = createModel2()
history = model2L2Reg.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val, y_val))
plotHistory(history)
score = model2L2Reg.evaluate(X_test, y_test, verbose=0)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_73 (Conv2D)           (None, 38, 38, 32)        320
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 36, 36, 64)        18496
# _________________________________________________________________
# conv2d_75 (Conv2D)           (None, 34, 34, 64)        36928
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_76 (Conv2D)           (None, 15, 15, 128)       73856
# _________________________________________________________________
# conv2d_77 (Conv2D)           (None, 13, 13, 128)       147584
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_78 (Conv2D)           (None, 4, 4, 256)         295168
# _________________________________________________________________
# conv2d_79 (Conv2D)           (None, 2, 2, 256)         590080
# _________________________________________________________________
# max_pooling2d_51 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_23 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_71 (Dense)             (None, 256)               65792
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_25 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_72 (Dense)             (None, 256)               65792
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 256)               1024
# _________________________________________________________________
# activation_26 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_73 (Dense)             (None, 31)                7967
# =================================================================
# Total params: 1,304,031
# Trainable params: 1,303,007
# Non-trainable params: 1,024
# _________________________________________________________________
# Train on 6000 samples, validate on 2000 samples
# Epoch 1/40
# 2560/6000 [===========>..................] - ETA: 32s - loss: 80.3004 - acc: 0.0961
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-125-47b0c6494c0b> in <module>
#       5           epochs=epochs,
#       6           verbose=1,
# ----> 7           validation_data=(X_val, y_val))
#       8 plotHistory(history)
#       9 score = model2L2Reg.evaluate(X_test, y_test, verbose=0)
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/Library/Python/3.6/lib/python/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
score
# Out:
# [1.6774757614135742, 0.6775]

# %%
model2L2Reg.save_weights('./models/model2L2Reg/model2_6775.h5')
model_json = model2L2Reg.to_json()
with open("./models/model2L2Reg/model2_6775.json", "w") as json_file:
    json_file.write(model_json)

# %%
kaggle_predictions_2 = model2L2Reg.predict(X_kaggle_2)
ts = time.time()
timestamp = int(ts)
savePredictions('./models/model2L2Reg/prediction_'+ str(timestamp) + '_' + str(score[1]) + '.csv', kaggle_predictions_2)

# %%
outputs = model1.predict(X_val)

# %%
from sklearn.metrics import f1_score

RFClassifier = RandomForestClassifier(n_estimators=94, criterion='gini')
RFClassifier.fit(outputs, list(map(lambda y: np.argmax(y), y_val)))
y_CNN_pred = model1.predict(X_test)
y_RF_pred = RFClassifier.predict(y_CNN_pred)
print(f1_score(list(map(lambda y: np.argmax(y), y_test)), y_RF_pred, average='micro'))
#visualizePredictionsJustWrong(X, y_pred, y, 10, 30, (40, 40))
# Out:
# 0.6575

# %%
lenet = leNet4()
history = lenet.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=200,
          verbose=1,
          validation_data=(X_val, y_val))
plotHistory(history)
score = lenet.evaluate(X_test, y_test, verbose=0)
score
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_39 (Conv2D)           (None, 37, 37, 4)         68
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 18, 18, 4)         0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 16, 16, 16)        592
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 8, 8, 16)          0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_55 (Dense)             (None, 120)               123000
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 120)               480
# _________________________________________________________________
# activation_17 (Activation)   (None, 120)               0
# _________________________________________________________________
# dense_56 (Dense)             (None, 128)               15488
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 128)               512
# _________________________________________________________________
# activation_18 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_57 (Dense)             (None, 40)                5160
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 40)                160
# _________________________________________________________________
# activation_19 (Activation)   (None, 40)                0
# _________________________________________________________________
# dense_58 (Dense)             (None, 31)                1271
# _________________________________________________________________
# activation_20 (Activation)   (None, 31)                0
# =================================================================
# Total params: 146,731
# Trainable params: 146,155
# Non-trainable params: 576
# _________________________________________________________________
# Train on 6000 samples, validate on 2000 samples
# Epoch 1/200
# 6000/6000 [==============================] - 4s 633us/step - loss: 4.3552 - acc: 0.2438 - val_loss: 3.6784 - val_acc: 0.2800
# Epoch 103/200
# 6000/6000 [==============================] - 2s 298us/step - loss: 0.5981 - acc: 0.9592 - val_loss: 4.1134 - val_acc: 0.4435
# Epoch 104/200
# 6000/6000 [==============================] - 2s 309us/step - loss: 0.5772 - acc: 0.9635 - val_loss: 3.9361 - val_acc: 0.4795
# Epoch 105/200
# 6000/6000 [==============================] - 2s 303us/step - loss: 0.5416 - acc: 0.9693 - val_loss: 3.8024 - val_acc: 0.4845
# Epoch 106/200
# 6000/6000 [==============================] - 2s 306us/step - loss: 0.4960 - acc: 0.9753 - val_loss: 3.7399 - val_acc: 0.4870
# Epoch 107/200
# 6000/6000 [==============================] - 2s 313us/step - loss: 0.4866 - acc: 0.9723 - val_loss: 4.2255 - val_acc: 0.4115
# Epoch 108/200
# 6000/6000 [==============================] - 2s 284us/step - loss: 0.5530 - acc: 0.9533 - val_loss: 4.2056 - val_acc: 0.4230
# Epoch 109/200
# 6000/6000 [==============================] - 2s 283us/step - loss: 0.6445 - acc: 0.9427 - val_loss: 4.2153 - val_acc: 0.4470
# Epoch 110/200
# 6000/6000 [==============================] - 2s 280us/step - loss: 0.6569 - acc: 0.9457 - val_loss: 4.0127 - val_acc: 0.4715
# Epoch 111/200
# 6000/6000 [==============================] - 2s 299us/step - loss: 0.6098 - acc: 0.9617 - val_loss: 4.0954 - val_acc: 0.4560
# Epoch 112/200
# 6000/6000 [==============================] - 2s 293us/step - loss: 0.5441 - acc: 0.9735 - val_loss: 4.0339 - val_acc: 0.4625
# Epoch 113/200
# 3776/6000 [=================>............] - ETA: 0s - loss: 0.5126 - acc: 0.9751
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-4e8abb34e0b7> in <module>
#       4           epochs=200,
#       5           verbose=1,
# ----> 6           validation_data=(X_val, y_val))
#       7 plotHistory(history)
#       8 score = lenet.evaluate(X_test, y_test, verbose=0)
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/Library/Python/3.6/lib/python/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model2 = createModel2()

# %%
history = model2.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val, y_val))
score = model.evaluate(X_test, y_test, verbose=0)

# %%
score
# Out:
# [1.4144920663833618, 0.6445]

# %%
# preprocessed_kaggle = load(PREPROCESSED_KAGGLE)
# X_kaggle = formatXData(list(map(lambda x: x[1], preprocessed_kaggle)))
# kaggle_predictions = model.predict(X_kaggle)

def savePredictions(outfile, predictions):
    with open(outfile,'w') as csvfile:
        fieldnames = ['Id', 'Category']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for i, prediction in enumerate(predictions):
            index = np.argmax(prediction)
            writer.writerow({'Id': i, 'Category': getCategoryOf(index)})

# %%
def visualizePredictions(images, predictions, start = 0, end = 10, shape=(40, 40)):
    fig, ax = plt.subplots(figsize=(len(CATEGORIES) + 1, end - start * 3))

    for i in list(range(start, end)):

        # plot probabilities:
        ax = plt.subplot2grid((end - start, 5), (i - start, 0), colspan=4);
        plt.bar(np.arange(len(CATEGORIES)), predictions[i], 0.35, align='center');
        plt.xticks(np.arange(len(CATEGORIES)), CATEGORIES)
        plt.tick_params(axis='x', bottom='off', top='off')
        plt.ylabel('Probability')
        plt.ylim(0,1)
        plt.subplots_adjust(hspace = 0.5)

        # plot picture:
        ax = plt.subplot2grid((end - start, 5), (i - start, 4));
        plt.imshow(images[i].reshape(shape),cmap='gray_r', interpolation='nearest');
        plt.xlabel(getCategoryOf(np.argmax(predictions[i]))); # get the label from the dict
        plt.xticks([])
        plt.yticks([])

#     for i, img in enumerate(images):
#         img = img[1].reshape(shape).astype(np.uint8)
#         f, axarr = plt.subplots(nrows=1, ncols=2, figsize=(20, 4))
#         f.suptitle(getCategoryOf(np.argmax(predictions[i])))
#         axarr[0].imshow(img, cmap='gray_r')
#         axarr[0].set_title('Image')
#         axarr[1].bar(range(0, len(CATEGORIES)), predictions[i])
#         plt.show()
def visualizePredictionsJustWrong(images, predictions, actual, start = 0, end = 10, shape=(40, 40)):
    fig, ax = plt.subplots(figsize=(len(CATEGORIES) + 1, 30))
    numFound = 0
    for i in range(start, len(images)):
        if getCategoryOf(np.argmax(predictions[i])) != getCategoryOf(np.argmax(actual[i])):
            # plot probabilities:
            ax = plt.subplot2grid((end - start, 5), (numFound, 0), colspan=4);
            plt.bar(np.arange(len(CATEGORIES)), predictions[i], 0.35, align='center');
            plt.xticks(np.arange(len(CATEGORIES)), CATEGORIES)
            plt.tick_params(axis='x', bottom='off', top='off')
            plt.ylabel('Probability')
            plt.ylim(0,1)
            plt.subplots_adjust(hspace = 0.5)

            # plot picture:
            ax = plt.subplot2grid((end - start, 5), (numFound, 4));
            plt.imshow(images[i].reshape(shape),cmap='gray_r', interpolation='nearest');
            plt.xlabel(getCategoryOf(np.argmax(predictions[i])) + "/" +getCategoryOf(np.argmax(actual[i]))); # get the label from the dict
            plt.xticks([])
            plt.yticks([])
            
            numFound += 1
            if numFound >= end - start:
                return

# %%
ts = time.time()
timestamp = int(ts)
savePredictions('./data/prediction_'+ str(timestamp) + '_' + str(score[1]) + '.csv', kaggle_predictions)

# %%
training_imgs = load(PREPROCESSED_TRAINING)
X,y = formatData(training_imgs, labels)
X_train, y_train, X_test, y_test, X_val, y_val = split(X,y)

# %%
model = createModel()
history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=10,
          verbose=1,
          validation_data=(X_val, y_val))
score = model.evaluate(X_test, y_test, verbose=0)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_160 (Conv2D)          (None, 38, 38, 32)        320
# _________________________________________________________________
# max_pooling2d_94 (MaxPooling (None, 19, 19, 32)        0
# _________________________________________________________________
# conv2d_161 (Conv2D)          (None, 17, 17, 64)        18496
# _________________________________________________________________
# max_pooling2d_95 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_130 (Dropout)        (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_162 (Conv2D)          (None, 6, 6, 128)         73856
# _________________________________________________________________
# dropout_131 (Dropout)        (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_163 (Conv2D)          (None, 4, 4, 512)         590336
# _________________________________________________________________
# dropout_132 (Dropout)        (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_38 (Flatten)         (None, 8192)              0
# _________________________________________________________________
# dense_81 (Dense)             (None, 512)               4194816
# _________________________________________________________________
# dropout_133 (Dropout)        (None, 512)               0
# _________________________________________________________________
# dense_82 (Dense)             (None, 31)                15903
# =================================================================
# Total params: 4,893,727
# Trainable params: 4,893,727
# Non-trainable params: 0
# _________________________________________________________________
# Train on 6000 samples, validate on 2000 samples
# Epoch 1/10
# 6000/6000 [==============================] - 20s 3ms/step - loss: 2.8502 - acc: 0.1980 - val_loss: 2.2645 - val_acc: 0.3610
# Epoch 2/10
# 6000/6000 [==============================] - 18s 3ms/step - loss: 2.1109 - acc: 0.3937 - val_loss: 1.8557 - val_acc: 0.4730
# Epoch 3/10
# 6000/6000 [==============================] - 17s 3ms/step - loss: 1.7726 - acc: 0.4807 - val_loss: 1.7251 - val_acc: 0.5255
# Epoch 4/10
# 6000/6000 [==============================] - 17s 3ms/step - loss: 1.5359 - acc: 0.5478 - val_loss: 1.5843 - val_acc: 0.5595
# Epoch 5/10
# 6000/6000 [==============================] - 17s 3ms/step - loss: 1.3414 - acc: 0.6073 - val_loss: 1.5036 - val_acc: 0.5875
# Epoch 6/10
# 6000/6000 [==============================] - 17s 3ms/step - loss: 1.1643 - acc: 0.6498 - val_loss: 1.4434 - val_acc: 0.6025
# Epoch 7/10
# 6000/6000 [==============================] - 17s 3ms/step - loss: 1.0203 - acc: 0.6885 - val_loss: 1.4039 - val_acc: 0.6130
# Epoch 8/10
# 6000/6000 [==============================] - 17s 3ms/step - loss: 0.9059 - acc: 0.7138 - val_loss: 1.4031 - val_acc: 0.6250
# Epoch 9/10
# 6000/6000 [==============================] - 17s 3ms/step - loss: 0.7746 - acc: 0.7535 - val_loss: 1.4203 - val_acc: 0.6220
# Epoch 10/10
# 6000/6000 [==============================] - 17s 3ms/step - loss: 0.6630 - acc: 0.7845 - val_loss: 1.5589 - val_acc: 0.6160

# %%
score
# Out:
# [1.4229669852256774, 0.6525]

# %%
preprocessed_kaggle_1 = load(PREPROCESSED_KAGGLE)
X_kaggle_1 = formatXData(list(map(lambda x: x[1], preprocessed_kaggle_1)))
kaggle_predictions_1 = model.predict(X_kaggle_1)

# %%
visualizePredictions(preprocessed_kaggle_1,kaggle_predictions_1, 10, 30)

# %%
ts = time.time()
timestamp = int(ts)
savePredictions('./data/prediction_'+ str(timestamp) + '_' + str(score[1]) + '.csv', kaggle_predictions)

# %% [markdown]
# # Interpolated AND bounded

# %%
PREPROCESSED_TRAINING_BI = "./data/preprocessed_interpolated_bounded.npy"
PREPROCESSED_KAGGLE_BI = "./data/processed_kaggle_interpolated_bounded.npy"

# %%
training_imgs_bi = load(PREPROCESSED_TRAINING_BI)
X,y = formatData(training_imgs_bi, labels)
X_train, y_train, X_test, y_test, X_val, y_val = split(X,y)
model_bi = createModel()
history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val, y_val))
score = model_bi.evaluate(X_test, y_test, verbose=0)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_168 (Conv2D)          (None, 38, 38, 32)        320
# _________________________________________________________________
# max_pooling2d_98 (MaxPooling (None, 19, 19, 32)        0
# _________________________________________________________________
# conv2d_169 (Conv2D)          (None, 17, 17, 64)        18496
# _________________________________________________________________
# max_pooling2d_99 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_138 (Dropout)        (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_170 (Conv2D)          (None, 6, 6, 128)         73856
# _________________________________________________________________
# dropout_139 (Dropout)        (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_171 (Conv2D)          (None, 4, 4, 512)         590336
# _________________________________________________________________
# dropout_140 (Dropout)        (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_40 (Flatten)         (None, 8192)              0
# _________________________________________________________________
# dense
# Epoch 39/40
# 6000/6000 [==============================] - 18s 3ms/step - loss: 0.0744 - acc: 0.9750 - val_loss: 2.8534 - val_acc: 0.6380
# Epoch 40/40
# 6000/6000 [==============================] - 18s 3ms/step - loss: 0.0580 - acc: 0.9810 - val_loss: 3.0493 - val_acc: 0.6310

# %%
score = model_bi.evaluate(X_test, y_test, verbose=0)
score
# Out:
# [3.4549782485961913, 0.0355]

# %%
preprocessed_kaggle_bi = load(PREPROCESSED_KAGGLE_BI)
X_kaggle_bi = formatXData(list(map(lambda x: x[1], preprocessed_kaggle_bi)))
kaggle_predictions_bi = model_bi.predict(X_kaggle_bi)

# %%
ts = time.time()
timestamp = int(ts)
savePredictions('./data/prediction_'+ str(timestamp) + '_' + str(score[1]) + '.csv', kaggle_predictions)

# %%
visualizePredictions(preprocessed_kaggle_bi,kaggle_predictions_bi, 10, 30)

# %%
model = createModel2()
history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val, y_val))
score = model.evaluate(X_test, y_test, verbose=0)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_143 (Conv2D)          (None, 38, 38, 32)        320
# _________________________________________________________________
# conv2d_144 (Conv2D)          (None, 36, 36, 64)        18496
# _________________________________________________________________
# conv2d_145 (Conv2D)          (None, 34, 34, 64)        36928
# _________________________________________________________________
# max_pooling2d_85 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# dropout_121 (Dropout)        (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_146 (Conv2D)          (None, 15, 15, 128)       73856
# _________________________________________________________________
# conv2d_147 (Conv2D)          (None, 13, 13, 128)       147584
# _________________________________________________________________
# max_pooling2d_86 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_122 (Dropout)        (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_148 (Conv2D)          (None, 4, 4, 256)         295168
# _________________________________________________________________
# conv2d_149 (Conv2D)          (None, 2, 2, 256)         590080
# _________________________________________________________________
# max_pooling2d_87 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# dropout_123 (Dropout)        (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_34 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dense_70 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_71 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_72 (Dense)             (None, 31)                7967
# =================================================================
# Total params: 1,301,983
# Trainable params: 1,301,983
# Non-trainable params: 0
# _________________________________________________________________
# Train on 6000 samples, validate on 2000 samples
# Epoch 1/40
# 6000/6000 [==============================] - 57s 9ms/step - loss: 3.0674 - acc: 0.1262 - val_loss: 2.6661 - val_acc: 0.2465
# Epoch 2/40
# 6000/6000 [==============================] - 54s 9ms/step - loss: 2.4639 - acc: 0.2773 - val_loss: 2.2785 - val_acc: 0.3250
# Epoch 3/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 2.1254 - acc: 0.3743 - val_loss: 1.9915 - val_acc: 0.4390
# Epoch 4/40
# 6000/6000 [==============================] - 51s 9ms/step - loss: 1.8225 - acc: 0.4643 - val_loss: 1.8182 - val_acc: 0.4900
# Epoch 5/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.2307 - acc: 0.9257 - val_loss: 2.0089 - val_acc: 0.6320
# Epoch 26/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.2572 - acc: 0.9208 - val_loss: 1.8727 - val_acc: 0.6325
# Epoch 27/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.2221 - acc: 0.9290 - val_loss: 2.0804 - val_acc: 0.6315
# Epoch 28/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.2076 - acc: 0.9335 - val_loss: 2.0652 - val_acc: 0.6445
# Epoch 29/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.1760 - acc: 0.9427 - val_loss: 2.2053 - val_acc: 0.6335
# Epoch 30/40
# 6000/6000 [==============================] - 53s 9ms/step - loss: 0.1831 - acc: 0.9415 - val_loss: 2.0096 - val_acc: 0.6290
# Epoch 31/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.1643 - acc: 0.9493 - val_loss: 2.3090 - val_acc: 0.6125
# Epoch 32/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.1855 - acc: 0.9433 - val_loss: 2.1824 - val_acc: 0.6325
# Epoch 33/40
# 6000/6000 [==============================] - 53s 9ms/step - loss: 0.1513 - acc: 0.9493 - val_loss: 2.2847 - val_acc: 0.6415
# Epoch 34/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.1775 - acc: 0.9460 - val_loss: 2.3242 - val_acc: 0.6280
# Epoch 35/40
# 6000/6000 [==============================] - 52s 9ms/step - loss: 0.1647 - acc: 0.9478 - val_loss: 2.1178 - val_acc: 0.6360
# Epoch 36/40
# 6000/6000 [==============================] - 51s 9ms/step - loss: 0.1520 - acc: 0.9510 - val_loss: 2.1909 - val_acc: 0.6270
# Epoch 37/40
# 6000/6000 [==============================] - 51s 9ms/step - loss: 0.1516 - acc: 0.9503 - val_loss: 2.2938 - val_acc: 0.6430
# Epoch 38/40
# 6000/6000 [==============================] - 51s 8ms/step - loss: 0.1483 - acc: 0.9543 - val_loss: 2.3765 - val_acc: 0.6295
# Epoch 39/40
# 6000/6000 [==============================] - 51s 8ms/step - loss: 0.1425 - acc: 0.9513 - val_loss: 2.3776 - val_acc: 0.6290
# Epoch 40/40
# 6000/6000 [==============================] - 51s 8ms/step - loss: 0.1395 - acc: 0.9567 - val_loss: 2.2606 - val_acc: 0.6435

# %%
score
# Out:
# [2.05893856048584, 0.6475]

# %%
kaggle_predictions = model.predict(X_kaggle)

# %%
ts = time.time()
timestamp = int(ts)
savePredictions('./data/prediction_'+ str(timestamp) + '_' + str(score[1]) + '.csv', kaggle_predictions)

# %%
visualizePredictions(preprocessed_kaggle[:100],kaggle_predictions[:100])

# %%
# Grabbed from: https://github.com/kradolfer/quickdraw-image-recognition/blob/master/quickdraw_image_recognition.ipynb
def cnn_model():
    # create model
    model = Sequential()
    model.add(Conv2D(42, (5, 5), input_shape=(40, 40, 1), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(15, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
model_cnn = cnn_model()
# Fit the model
model_cnn.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=40, batch_size=200)
# Final evaluation of the model
scores = model_cnn.evaluate(X_test, y_test, verbose=0)
# Out:
# Train on 6000 samples, validate on 2000 samples
# Epoch 1/40
# 6000/6000 [==============================] - 8s 1ms/step - loss: 3.2108 - acc: 0.1033 - val_loss: 2.7961 - val_acc: 0.2155
# Epoch 2/40
# 2400/6000 [===========>..................] - ETA: 3s - loss: 2.7181 - acc: 0.2471
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-242-755646525e8a> in <module>
#       1 model_cnn = cnn_model()
#       2 # Fit the model
# ----> 3 model_cnn.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=40, batch_size=200)
#       4 # Final evaluation of the model
#       5 scores = model_cnn.evaluate(X_test, y_test, verbose=0)
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/Library/Python/3.6/lib/python/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
PREPROCESSED_TRAINING_SMALL = "./data/preprocessed_interpolated_28_28.npy"
PREPROCESSED_KAGGLE_SMALL = "./data/preprocessed_kaggle_interpolated_28_28.npy"

# %%
training_imgs_small = load(PREPROCESSED_TRAINING_SMALL)
X_small,y_small = formatData(training_imgs_small, labels, 28)
X_train, y_train, X_test, y_test, X_val, y_val = split(X_small,y_small)

# %%
model_bi = createModel()
history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val, y_val))
score = model_bi.evaluate(X_test, y_test, verbose=0)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 38, 38, 32)        320
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 19, 19, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 17, 17, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 6, 6, 128)         73856
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 4, 4, 512)         590336
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 31)                15903
# =================================================================
# Total params: 4,893,727
# Trainable params: 4,893,727
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-c5bd07218710> in <module>
#       4           epochs=epochs,
#       5           verbose=1,
# ----> 6           validation_data=(X_val, y_val))
#       7 score = model_bi.evaluate(X_test, y_test, verbose=0)
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking input: expected conv2d_8_input to have shape (40, 40, 1) but got array with shape (28, 28, 1)

# %% [markdown]
# # Bounding Box tests

# %%
PREPROCESSED_TRAINING_BOUNDING_BOX = "./data/train_preprocessed_boundingbox.npy"
PREPROCESSED_KAGGLE_BOUNDING_BOX = "./data/kaggle_preprocessed_boundingbox.npy"
training_imgs_boundingbox = load(PREPROCESSED_TRAINING_BOUNDING_BOX)
X_boundingbox,y_boundingbox = formatData(training_imgs_boundingbox, labels)
X_train_bb, y_train_bb, X_test_bb, y_test_bb, X_val_bb, y_val_bb = split(X_boundingbox,y_boundingbox)
model1_bb = createModel()
history = model1_bb.fit(X_train_bb, y_train_bb,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val_bb, y_val_bb))
score = model1_bb.evaluate(X_test_bb, y_test_bb, verbose=0)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_104 (Conv2D)          (None, 38, 38, 32)        320
# _________________________________________________________________
# max_pooling2d_64 (MaxPooling (None, 19, 19, 32)        0
# _________________________________________________________________
# conv2d_105 (Conv2D)          (None, 17, 17, 64)        18496
# _________________________________________________________________
# max_pooling2d_65 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_65 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_106 (Conv2D)          (None, 6, 6, 128)         73856
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_107 (Conv2D)          (None, 4, 4, 512)         590336
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_30 (Flatten)         (None, 8192)              0
# _________________________________________________________________
# dense_86 (Dense)             (None, 512)               4194816
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_87 (Dense)             (None, 31)                15903
# =================================================================
# Total params: 4,895,775
# Trainable params: 4,894,751
# Non-trainable params: 1,024
# _________________________________________________________________
# Train on 8000 samples, validate on 1000 samples
# Epoch 1/40
# 8000/8000 [==============================] - 27s 3ms/step - loss: 2.8814 - acc: 0.2338 - val_loss: 2.6630 - val_acc: 0.2720
# Epoch 2/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 2.1263 - acc: 0.4040 - val_loss: 2.1577 - val_acc: 0.4070
# Epoch 3/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 1.7737 - acc: 0.4974 - val_loss: 1.6766 - val_acc: 0.5330
# Epoch 4/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 1.5362 - acc: 0.5621 - val_loss: 1.7548 - val_acc: 0.5050
# Epoch 5/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 1.3716 - acc: 0.6054 - val_loss: 1.5309 - val_acc: 0.5580
# Epoch 6/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.2456 - acc: 0.6398 - val_loss: 1.3615 - val_acc: 0.6220
# Epoch 7/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 1.1090 - acc: 0.6676 - val_loss: 1.3832 - val_acc: 0.6170
# Epoch 8/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 1.0391 - acc: 0.6906 - val_loss: 1.2343 - val_acc: 0.6450
# Epoch 9/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.9221 - acc: 0.7223 - val_loss: 1.2423 - val_acc: 0.6650
# Epoch 10/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.8265 - acc: 0.7507 - val_loss: 1.1917 - val_acc: 0.6790
# Epoch 11/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.7284 - acc: 0.7758 - val_loss: 1.2214 - val_acc: 0.6710
# Epoch 12/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.6638 - acc: 0.7914 - val_loss: 1.1541 - val_acc: 0.6960
# Epoch 13/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.5991 - acc: 0.8114 - val_loss: 1.2228 - val_acc: 0.6740
# Epoch 14/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.5364 - acc: 0.8341 - val_loss: 1.2101 - val_acc: 0.6880
# Epoch 15/40
# 8000/8000 [==============================] - 26s 3ms/step - loss: 0.4576 - acc: 0.8534 - val_loss: 1.2067 - val_acc: 0.6930
# Epoch 16/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.4434 - acc: 0.8563 - val_loss: 1.2530 - val_acc: 0.6960
# Epoch 17/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.3943 - acc: 0.8705 - val_loss: 1.3211 - val_acc: 0.7050
# Epoch 18/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.3493 - acc: 0.8864 - val_loss: 1.3058 - val_acc: 0.6770
# Epoch 19/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.3366 - acc: 0.8907 - val_loss: 1.3021 - val_acc: 0.6990
# Epoch 20/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.2972 - acc: 0.9040 - val_loss: 1.3534 - val_acc: 0.6930
# Epoch 21/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.2742 - acc: 0.9133 - val_loss: 1.3021 - val_acc: 0.7030
# Epoch 22/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.2611 - acc: 0.9140 - val_loss: 1.3388 - val_acc: 0.6980
# Epoch 23/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.2488 - acc: 0.9184 - val_loss: 1.2988 - val_acc: 0.7170
# Epoch 24/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.2463 - acc: 0.9170 - val_loss: 1.3213 - val_acc: 0.7080
# Epoch 25/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.2280 - acc: 0.9224 - val_loss: 1.4098 - val_acc: 0.6980
# Epoch 26/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.2083 - acc: 0.9304 - val_loss: 1.3845 - val_acc: 0.6970
# Epoch 27/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.1961 - acc: 0.9355 - val_loss: 1.3252 - val_acc: 0.7190
# Epoch 28/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.1698 - acc: 0.9460 - val_loss: 1.3732 - val_acc: 0.6940
# Epoch 29/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.1904 - acc: 0.9360 - val_loss: 1.3726 - val_acc: 0.7080
# Epoch 30/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.1808 - acc: 0.9410 - val_loss: 1.4413 - val_acc: 0.7100
# Epoch 31/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1661 - acc: 0.9481 - val_loss: 1.4711 - val_acc: 0.7080
# Epoch 32/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1646 - acc: 0.9475 - val_loss: 1.4013 - val_acc: 0.7090
# Epoch 33/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1585 - acc: 0.9481 - val_loss: 1.4823 - val_acc: 0.6970
# Epoch 34/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1624 - acc: 0.9461 - val_loss: 1.4220 - val_acc: 0.7110
# Epoch 35/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1604 - acc: 0.9472 - val_loss: 1.4477 - val_acc: 0.6980
# Epoch 36/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.1557 - acc: 0.9500 - val_loss: 1.5864 - val_acc: 0.6860
# Epoch 37/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.1470 - acc: 0.9523 - val_loss: 1.4973 - val_acc: 0.6960
# Epoch 38/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.1332 - acc: 0.9559 - val_loss: 1.5745 - val_acc: 0.7010
# Epoch 39/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1294 - acc: 0.9579 - val_loss: 1.6077 - val_acc: 0.6900
# Epoch 40/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.1378 - acc: 0.9579 - val_loss: 1.5438 - val_acc: 0.6960

# %%
score = model1_bb.evaluate(X_test_bb, y_test_bb, verbose=0)
score
# Out:
# [1.6610751371383667, 0.697]

# %%
plotHistory(history)

# %%
preprocessed_kaggle_boundingbox = load(PREPROCESSED_KAGGLE_BOUNDING_BOX)
X_kaggle_bb = formatXData(list(map(lambda x: x[1], preprocessed_kaggle_boundingbox)))

# %%
kaggle_predictions_boundingbox = model1_bb.predict(X_kaggle_bb)
ts = time.time()
timestamp = int(ts)
savePredictions('./models/model1_boundingbox/prediction_'+ str(timestamp) + '_' + str(score[1]) + '.csv', kaggle_predictions_boundingbox)

# %%
visualizePredictions(X_kaggle_bb,kaggle_predictions_boundingbox, start = 0, end = 100)

# %%
def createModel1WithLoss(input_shape=(40, 40, 1)):
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 kernel_initializer='he_normal',
                 input_shape=input_shape))

    model.add(MaxPooling2D((2, 2)))
#     model.add(Dropout(0.25))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Dropout(0.4))
    model.add(Conv2D(512, (3, 3), activation='relu'))
    model.add(Dropout(0.3))
    model.add(Flatten())
    model.add(Dense(512, activation='relu', kernel_regularizer=keras.regularizers.l2(0.1)))
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])
    model.summary()
    return model

# %%
model1_bb_WithLoss = createModel1WithLoss()
history = model1_bb_WithLoss.fit(X_train_bb, y_train_bb,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val_bb, y_val_bb))
score = model1_bb_WithLoss.evaluate(X_test_bb, y_test_bb, verbose=0)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_100 (Conv2D)          (None, 38, 38, 32)        320
# _________________________________________________________________
# max_pooling2d_62 (MaxPooling (None, 19, 19, 32)        0
# _________________________________________________________________
# conv2d_101 (Conv2D)          (None, 17, 17, 64)        18496
# _________________________________________________________________
# max_pooling2d_63 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_102 (Conv2D)          (None, 6, 6, 128)         73856
# _________________________________________________________________
# dropout_62 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_103 (Conv2D)          (None, 4, 4, 512)         590336
# _________________________________________________________________
# dropout_63 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_29 (Flatten)         (None, 8192)              0
# _________________________________________________________________
# dense_84 (Dense)             (None, 512)               4194816
# _________________________________________________________________
# dropout_64 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_85 (Dense)             (None, 31)                15903
# =================================================================
# Total params: 4,893,727
# Trainable params: 4,893,727
# Non-trainable params: 0
# _________________________________________________________________
# Train on 8000 samples, validate on 1000 samples
# Epoch 1/40
# 8000/8000 [==============================] - 27s 3ms/step - loss: 21.3394 - acc: 0.1903 - val_loss: 3.4021 - val_acc: 0.3060
# Epoch 2/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 3.2363 - acc: 0.3332 - val_loss: 2.9400 - val_acc: 0.4000
# Epoch 3/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 3.0463 - acc: 0.3770 - val_loss: 2.7939 - val_acc: 0.4350
# Epoch 4/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 2.8871 - acc: 0.4226 - val_loss: 2.6870 - val_acc: 0.4660
# Epoch 5/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 2.7919 - acc: 0.4479 - val_loss: 2.6189 - val_acc: 0.5070
# Epoch 6/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 2.6876 - acc: 0.4861 - val_loss: 2.6420 - val_acc: 0.5390
# Epoch 7/40
# 8000/8000 [==============================] - 23s 3ms/step - loss: 2.6438 - acc: 0.4956 - val_loss: 2.4177 - val_acc: 0.5270
# Epoch 8/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 2.5509 - acc: 0.5229 - val_loss: 2.4090 - val_acc: 0.5740
# Epoch 9/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 2.5127 - acc: 0.5473 - val_loss: 2.4139 - val_acc: 0.5820
# Epoch 10/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 2.4617 - acc: 0.5521 - val_loss: 2.3019 - val_acc: 0.5840
# Epoch 11/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 2.4288 - acc: 0.5637 - val_loss: 2.2385 - val_acc: 0.6080
# Epoch 12/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 2.3038 - acc: 0.5790 - val_loss: 2.2721 - val_acc: 0.5860
# Epoch 13/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 2.3167 - acc: 0.5840 - val_loss: 2.3226 - val_acc: 0.6300
# Epoch 14/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 2.3107 - acc: 0.5914 - val_loss: 2.2576 - val_acc: 0.6340
# Epoch 15/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 2.2447 - acc: 0.6018 - val_loss: 2.1178 - val_acc: 0.6480
# Epoch 16/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 2.2129 - acc: 0.6150 - val_loss: 2.2117 - val_acc: 0.6180
# Epoch 17/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 2.1798 - acc: 0.6159 - val_loss: 2.1031 - val_acc: 0.6320
# Epoch 18/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 2.1711 - acc: 0.6194 - val_loss: 2.1066 - val_acc: 0.6470
# Epoch 19/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 2.1528 - acc: 0.6364 - val_loss: 2.0705 - val_acc: 0.6520
# Epoch 20/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 2.0986 - acc: 0.6398 - val_loss: 2.1192 - val_acc: 0.6520
# Epoch 21/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 2.0931 - acc: 0.6446 - val_loss: 2.1084 - val_acc: 0.6600
# Epoch 22/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 2.0558 - acc: 0.6419 - val_loss: 2.0459 - val_acc: 0.6690
# Epoch 23/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 2.0474 - acc: 0.6530 - val_loss: 2.0789 - val_acc: 0.6620
# Epoch 24/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 2.0409 - acc: 0.6554 - val_loss: 1.9397 - val_acc: 0.6940
# Epoch 25/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.9706 - acc: 0.6660 - val_loss: 2.0776 - val_acc: 0.6550
# Epoch 26/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 2.0428 - acc: 0.6667 - val_loss: 1.9610 - val_acc: 0.6810
# Epoch 27/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.9837 - acc: 0.6656 - val_loss: 2.0017 - val_acc: 0.6750
# Epoch 28/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.9590 - acc: 0.6686 - val_loss: 1.9318 - val_acc: 0.6880
# Epoch 29/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.8912 - acc: 0.6775 - val_loss: 1.9849 - val_acc: 0.6810
# Epoch 30/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.9380 - acc: 0.6793 - val_loss: 2.0426 - val_acc: 0.6630
# Epoch 31/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.9610 - acc: 0.6724 - val_loss: 1.9380 - val_acc: 0.6990
# Epoch 32/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.9533 - acc: 0.6874 - val_loss: 1.9227 - val_acc: 0.7080
# Epoch 33/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.9248 - acc: 0.6839 - val_loss: 1.8754 - val_acc: 0.7120
# Epoch 34/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.8945 - acc: 0.6870 - val_loss: 1.8846 - val_acc: 0.7010
# Epoch 35/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.8349 - acc: 0.6984 - val_loss: 1.9317 - val_acc: 0.6960
# Epoch 36/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.8793 - acc: 0.6949 - val_loss: 1.8601 - val_acc: 0.7050
# Epoch 37/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.8722 - acc: 0.6986 - val_loss: 1.8935 - val_acc: 0.7220
# Epoch 38/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.8229 - acc: 0.7004 - val_loss: 1.8087 - val_acc: 0.7320
# Epoch 39/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.8532 - acc: 0.7032 - val_loss: 1.9511 - val_acc: 0.7090
# Epoch 40/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.8317 - acc: 0.7034 - val_loss: 1.9136 - val_acc: 0.7090

# %%
score = model1_bb_WithLoss.evaluate(X_test_bb, y_test_bb, verbose=0)

# %%
score
# Out:
# [1.8142251262664795, 0.732]

# %%
model1_bb_WithLoss.fit(X_train_bb, y_train_bb,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_val_bb, y_val_bb))
# Out:
# Train on 8000 samples, validate on 1000 samples
# Epoch 1/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.8105 - acc: 0.7095 - val_loss: 1.8994 - val_acc: 0.6990
# Epoch 2/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.8360 - acc: 0.7071 - val_loss: 1.8882 - val_acc: 0.7200
# Epoch 3/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.8152 - acc: 0.7087 - val_loss: 2.0604 - val_acc: 0.7090
# Epoch 4/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.8441 - acc: 0.7094 - val_loss: 1.9218 - val_acc: 0.7110
# Epoch 5/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.8097 - acc: 0.7119 - val_loss: 1.9006 - val_acc: 0.6950
# Epoch 6/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.7736 - acc: 0.7103 - val_loss: 1.8378 - val_acc: 0.7280
# Epoch 7/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.7835 - acc: 0.7210 - val_loss: 1.8254 - val_acc: 0.7170
# Epoch 8/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.7508 - acc: 0.7241 - val_loss: 1.8889 - val_acc: 0.7180
# Epoch 9/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.7478 - acc: 0.7258 - val_loss: 1.9001 - val_acc: 0.7000
# Epoch 10/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.7446 - acc: 0.7219 - val_loss: 1.8269 - val_acc: 0.7230
# Epoch 11/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.7234 - acc: 0.7310 - val_loss: 1.8469 - val_acc: 0.7220
# Epoch 12/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.7169 - acc: 0.7306 - val_loss: 1.8261 - val_acc: 0.7120
# Epoch 13/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.7799 - acc: 0.7275 - val_loss: 1.9212 - val_acc: 0.7240
# Epoch 14/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.7453 - acc: 0.7309 - val_loss: 1.8099 - val_acc: 0.7230
# Epoch 15/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.7465 - acc: 0.7288 - val_loss: 1.8627 - val_acc: 0.7170
# Epoch 16/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.6819 - acc: 0.7309 - val_loss: 1.7553 - val_acc: 0.7230
# Epoch 17/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.6838 - acc: 0.7431 - val_loss: 1.8218 - val_acc: 0.7300
# Epoch 18/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.6734 - acc: 0.7405 - val_loss: 1.8626 - val_acc: 0.7180
# Epoch 19/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.6987 - acc: 0.7346 - val_loss: 1.9029 - val_acc: 0.7200
# Epoch 20/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.7094 - acc: 0.7394 - val_loss: 1.8009 - val_acc: 0.7410
# Epoch 21/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.6822 - acc: 0.7448 - val_loss: 1.8320 - val_acc: 0.7230
# Epoch 22/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.6451 - acc: 0.7496 - val_loss: 1.8238 - val_acc: 0.7360
# Epoch 23/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.6719 - acc: 0.7435 - val_loss: 1.8391 - val_acc: 0.7300
# Epoch 24/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.6628 - acc: 0.7489 - val_loss: 1.8671 - val_acc: 0.7250
# Epoch 25/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.6367 - acc: 0.7500 - val_loss: 1.7935 - val_acc: 0.7330
# Epoch 26/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.6436 - acc: 0.7496 - val_loss: 1.9050 - val_acc: 0.7160
# Epoch 27/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.6261 - acc: 0.7585 - val_loss: 1.7830 - val_acc: 0.7450
# Epoch 28/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.6581 - acc: 0.7545 - val_loss: 1.9576 - val_acc: 0.7070
# Epoch 29/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.6401 - acc: 0.7582 - val_loss: 1.8213 - val_acc: 0.7420
# Epoch 30/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.6400 - acc: 0.7488 - val_loss: 1.7906 - val_acc: 0.7400
# Epoch 31/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.6618 - acc: 0.7559 - val_loss: 1.9270 - val_acc: 0.7180
# Epoch 32/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.6482 - acc: 0.7556 - val_loss: 1.8584 - val_acc: 0.7260
# Epoch 33/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.6116 - acc: 0.7621 - val_loss: 1.8895 - val_acc: 0.7340
# Epoch 34/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.6554 - acc: 0.7602 - val_loss: 1.7845 - val_acc: 0.7430
# Epoch 35/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.5936 - acc: 0.7651 - val_loss: 1.7559 - val_acc: 0.7380
# Epoch 36/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.6168 - acc: 0.7712 - val_loss: 1.7709 - val_acc: 0.7400
# Epoch 37/40
# 8000/8000 [==============================] - 24s 3ms/step - loss: 1.6057 - acc: 0.7680 - val_loss: 1.7275 - val_acc: 0.7390
# Epoch 38/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.6457 - acc: 0.7599 - val_loss: 1.8278 - val_acc: 0.7400
# Epoch 39/40
# 8000/8000 [==============================] - 26s 3ms/step - loss: 1.5965 - acc: 0.7632 - val_loss: 1.8585 - val_acc: 0.7290
# Epoch 40/40
# 8000/8000 [==============================] - 25s 3ms/step - loss: 1.6081 - acc: 0.7701 - val_loss: 1.8186 - val_acc: 0.7430

# %%
kaggle_predictions_boundingbox = model1_bb_WithLoss.predict(X_kaggle_bb)
ts = time.time()
timestamp = int(ts)
savePredictions('./models/model1_boundingbox_L2/prediction_'+ str(timestamp) + '_' + str(score[1]) + '.csv', kaggle_predictions_boundingbox)

# %%
visualizePredictions(X_kaggle_bb,kaggle_predictions_boundingbox, start = 0, end = 100)
